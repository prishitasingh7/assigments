# %%
i pip install matplotlib
i pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('/Users/prishitasingh/Desktop/Machine Learning/pandas/Titanic-Dataset.csv')
mpg=pd.read_csv('/Users/prishitasingh/Desktop/Machine Learning/pandas/mpg.csv')
