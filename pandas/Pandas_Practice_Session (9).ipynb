# %% [markdown]
# # 🐼 **Pandas Practice 1**
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook._
#
# ---

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/skm22/Introduction_To_Machine_Learning/main/Data/mpg.csv"
df = pd.read_csv(url)
df.head()

# %%
import pandas as pd

df = pd.read_csv("/Users/prishitasingh/Desktop/Machine Learning/pandas/mpg.csv")

df.head(7), df.tail(4)
# Out:
# (    mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  0  18.0          8         307.0       130.0    3504          12.0
#  1  15.0          8         350.0       165.0    3693          11.5
#  2  18.0          8         318.0       150.0    3436          11.0
#  3  16.0          8         304.0       150.0    3433          12.0
#  4  17.0          8         302.0       140.0    3449          10.5
#  5  15.0          8         429.0       198.0    4341          10.0
#  6  14.0          8         454.0       220.0    4354           9.0
#
#     model_year origin                       name
#  0          70    usa  chevrolet chevelle malibu
#  1          70    usa          buick skylark 320
#  2          70    usa         plymouth satellite
#  3          70    usa              amc rebel sst
#  4          70    usa                ford torino
#  5          70    usa           ford galaxie 500
#  6          70    usa           chevrolet impala  ,
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  394  44.0          4          97.0        52.0    2130          24.6
#  395  32.0          4         135.0        84.0    2295          11.6
#  396  28.0          4         120.0        79.0    2625          18.6
#  397  31.0          4         119.0        82.0    2720          19.4
#
#       model_year  origin           name
#  394          82  europe      vw pickup
#  395          82     usa  dodge rampage
#  396          82     usa    ford ranger
#  397          82     usa     chevy s-10  )

# %%
df.head(7), df.tail(4)
# Out:
# (    mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  0  18.0          8         307.0       130.0    3504          12.0
#  1  15.0          8         350.0       165.0    3693          11.5
#  2  18.0          8         318.0       150.0    3436          11.0
#  3  16.0          8         304.0       150.0    3433          12.0
#  4  17.0          8         302.0       140.0    3449          10.5
#  5  15.0          8         429.0       198.0    4341          10.0
#  6  14.0          8         454.0       220.0    4354           9.0
#
#     model_year origin                       name
#  0          70    usa  chevrolet chevelle malibu
#  1          70    usa          buick skylark 320
#  2          70    usa         plymouth satellite
#  3          70    usa              amc rebel sst
#  4          70    usa                ford torino
#  5          70    usa           ford galaxie 500
#  6          70    usa           chevrolet impala  ,
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  394  44.0          4          97.0        52.0    2130          24.6
#  395  32.0          4         135.0        84.0    2295          11.6
#  396  28.0          4         120.0        79.0    2625          18.6
#  397  31.0          4         119.0        82.0    2720          19.4
#
#       model_year  origin           name
#  394          82  europe      vw pickup
#  395          82     usa  dodge rampage
#  396          82     usa    ford ranger
#  397          82     usa     chevy s-10  )

# %% [markdown]
# # 🔍 **1. Basic Exploration**
#
# ### _`.head(n)` / `.tail(n)` → first/last rows | `.shape` → (rows, cols) | `.columns` → column names | `.dtypes` → column data types_
#
# ---

# %% [markdown]
# **Q1.1 Display the first 7 rows and the last 4 rows of `df`.**

# %%
# Write your code here
df.head(7), df.tail(4)
# Out:
# (    mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  0  18.0          8         307.0       130.0    3504          12.0
#  1  15.0          8         350.0       165.0    3693          11.5
#  2  18.0          8         318.0       150.0    3436          11.0
#  3  16.0          8         304.0       150.0    3433          12.0
#  4  17.0          8         302.0       140.0    3449          10.5
#  5  15.0          8         429.0       198.0    4341          10.0
#  6  14.0          8         454.0       220.0    4354           9.0
#
#     model_year origin                       name
#  0          70    usa  chevrolet chevelle malibu
#  1          70    usa          buick skylark 320
#  2          70    usa         plymouth satellite
#  3          70    usa              amc rebel sst
#  4          70    usa                ford torino
#  5          70    usa           ford galaxie 500
#  6          70    usa           chevrolet impala  ,
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
#  394  44.0          4          97.0        52.0    2130          24.6
#  395  32.0          4         135.0        84.0    2295          11.6
#  396  28.0          4         120.0        79.0    2625          18.6
#  397  31.0          4         119.0        82.0    2720          19.4
#
#       model_year  origin           name
#  394          82  europe      vw pickup
#  395          82     usa  dodge rampage
#  396          82     usa    ford ranger
#  397          82     usa     chevy s-10  )

# %% [markdown]
# **Q1.2 Print the shape of `df`, the list of column names, and the dtype of each column.**

# %%
# Write your code here
print("Shape:", df.shape)

print("Column Names:")
print(df.columns.tolist())

print("Data Types:")
print(df.dtypes)
# Out:
# Shape: (398, 9)
# Column Names:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'name']
# Data Types:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %% [markdown]
# **Q1.3 Use `.info()` and `.describe()` to get a summary of the dataset. What does `.describe()` tell you about the `mpg` column?**

# %%
# Write your code here
# Dataset information
df.info()

# Statistical summary
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# **Q1.4 Unpack `.shape` into two variables (e.g. `rows, cols = df.shape`) and print how many rows and columns the dataset has.**

# %%
# Write your code here
rows, cols = df.shape

print("Number of rows:", rows)
print("Number of columns:", cols)
# Out:
# Number of rows: 398
# Number of columns: 9

# %% [markdown]
# # 🎯 **2. Selecting Columns & Rows**
#
# ### _`df['col']` → single column (Series) | `df[['a','b']]` → multiple columns (DataFrame) | `.loc[rows, cols]` → label-based | `.iloc[rows, cols]` → position-based_
#
# ---

# %% [markdown]
# **Q2.1 Select only the `mpg` and `name` columns and store in a new variable.**

# %%
# Write your code here
new_df = df[["mpg", "name"]]

print(new_df)
# Out:
#       mpg                       name
# 0    18.0  chevrolet chevelle malibu
# 1    15.0          buick skylark 320
# 2    18.0         plymouth satellite
# 3    16.0              amc rebel sst
# 4    17.0                ford torino
# ..    ...                        ...
# 393  27.0            ford mustang gl
# 394  44.0                  vw pickup
# 395  32.0              dodge rampage
# 396  28.0                ford ranger
# 397  31.0                 chevy s-10
#
# [398 rows x 2 columns]

# %% [markdown]
# **Q2.2 Use `.loc` to get rows 5 to 10 (inclusive) showing only the `mpg`, `cylinders`, and `horsepower` columns.**

# %%
# Write your code here
result = df.loc[5:10, ["mpg", "cylinders", "horsepower"]]

print(result)
# Out:
#      mpg  cylinders  horsepower
# 5   15.0          8       198.0
# 6   14.0          8       220.0
# 7   14.0          8       215.0
# 8   14.0          8       225.0
# 9   15.0          8       190.0
# 10  15.0          8       170.0

# %% [markdown]
# **Q2.3 Use `.iloc` to get the first 3 rows and the last 2 columns of `df`.**

# %%
# Write your code here
result = df.iloc[:3, -2:]

print(result)
# Out:
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite

# %% [markdown]
# **Q2.4 Select the `mpg` column using both `df['mpg']` and `df.mpg`, and confirm that both give the same result.**

# %%
# Write your code here

mpg_1 = df["mpg"]
mpg_2 = df.mpg

print(mpg_1)
print(mpg_2)

print("Both are same:", mpg_1.equals(mpg_2))
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64
# Both are same: True

# %% [markdown]
# # 🧮 **3. Filtering / Boolean Indexing**
#
# ### _`df[df['col'] > x]` → condition-based filtering | combine conditions with `&` (and) / `|` (or), each wrapped in `()`_
#
# ---

# %% [markdown]
# **Q3.1 Filter and display all cars with `mpg` greater than 30.**

# %%
# Write your code here
result = df[df["mpg"] > 30]

print(result)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
# 131  32.0          4          71.0        65.0    1836          21.0
# 144  31.0          4          76.0        52.0    1649          16.5
# ..    ...        ...           ...         ...     ...           ...
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                 name
# 53           71   japan  toyota corolla 1200
# 54           71   japan          datsun 1200
# 129          74   japan          datsun b210
# 131          74   japan  toyota corolla 1200
# 144          74   japan        toyota corona
# ..          ...     ...                  ...
# 390          82   japan     toyota celica gt
# 391          82     usa    dodge charger 2.2
# 394          82  europe            vw pickup
# 395          82     usa        dodge rampage
# 397          82     usa           chevy s-10
#
# [85 rows x 9 columns]

# %% [markdown]
# **Q3.2 Filter all cars from `origin == 'japan'` that also have `horsepower` less than 100.**

# %%
# Write your code here
result = df[(df["origin"] == "japan") & (df["horsepower"] < 100)]

print(result)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 29   27.0          4          97.0        88.0    2130          14.5
# 31   25.0          4         113.0        95.0    2228          14.0
# 53   31.0          4          71.0        65.0    1773          19.0
# ..    ...        ...           ...         ...     ...           ...
# 382  34.0          4         108.0        70.0    2245          16.9
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 390  32.0          4         144.0        96.0    2665          13.9
#
#      model_year origin                   name
# 14           70  japan  toyota corona mark ii
# 18           70  japan           datsun pl510
# 29           71  japan           datsun pl510
# 31           71  japan          toyota corona
# 53           71  japan    toyota corolla 1200
# ..          ...    ...                    ...
# 382          82  japan         toyota corolla
# 383          82  japan            honda civic
# 384          82  japan     honda civic (auto)
# 385          82  japan          datsun 310 gx
# 390          82  japan       toyota celica gt
#
# [71 rows x 9 columns]

# %% [markdown]
# **Q3.3 Filter all cars with `cylinders == 4` and `model_year >= 78`.**

# %%
# Write your code here
result = df[(df["cylinders"] == 4) & (df["model_year"] >= 78)]

print(result)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 244  43.1          4          90.0        48.0    1985          21.5
# 245  36.1          4          98.0        66.0    1800          14.4
# 246  32.8          4          78.0        52.0    1985          19.4
# 247  39.4          4          85.0        70.0    2070          18.6
# 248  36.1          4          91.0        60.0    1800          16.4
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                             name
# 244          78  europe  volkswagen rabbit custom diesel
# 245          78     usa                      ford fiesta
# 246          78   japan                 mazda glc deluxe
# 247          78   japan                   datsun b210 gx
# 248          78   japan                 honda civic cvcc
# ..          ...     ...                              ...
# 393          82     usa                  ford mustang gl
# 394          82  europe                        vw pickup
# 395          82     usa                    dodge rampage
# 396          82     usa                      ford ranger
# 397          82     usa                       chevy s-10
#
# [103 rows x 9 columns]

# %% [markdown]
# **Q3.4 Filter all cars where `origin` is **not** `'usa'`, using the `~` (NOT) operator.**

# %%
# Write your code here
result = df[~(df["origin"] == "usa")]

print(result)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 14   24.0          4         113.0        95.0    2372          15.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# ..    ...        ...           ...         ...     ...           ...
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 390  32.0          4         144.0        96.0    2665          13.9
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                          name
# 14           70   japan         toyota corona mark ii
# 18           70   japan                  datsun pl510
# 19           70  europe  volkswagen 1131 deluxe sedan
# 20           70  europe                   peugeot 504
# 21           70  europe                   audi 100 ls
# ..          ...     ...                           ...
# 383          82   japan                   honda civic
# 384          82   japan            honda civic (auto)
# 385          82   japan                 datsun 310 gx
# 390          82   japan              toyota celica gt
# 394          82  europe                     vw pickup
#
# [149 rows x 9 columns]

# %% [markdown]
# # ↕️ **4. Sorting**
#
# ### _`.sort_values('col')` → ascending by default | `ascending=False` → descending | pass a list of columns for multi-level sort_
#
# ---

# %% [markdown]
# **Q4.1 Sort the dataset by `mpg` in descending order and show the top 5 most fuel-efficient cars (name + mpg).**

# %%
# Write your code here
result = df.sort_values("mpg", ascending=False)

print(result[["name", "mpg"]].head(5))
# Out:
#                      name   mpg
# 322             mazda glc  46.6
# 329   honda civic 1500 gl  44.6
# 325  vw rabbit c (diesel)  44.3
# 394             vw pickup  44.0
# 326    vw dasher (diesel)  43.4

# %% [markdown]
# **Q4.2 Sort the dataset first by `weight` (ascending) and then by `horsepower` (descending).**

# %%
# Write your code here
result = df.sort_values(
    by=["weight", "horsepower"],
    ascending=[True, False]
)

print(result)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 54   35.0          4          72.0        69.0    1613          18.0
# 144  31.0          4          76.0        52.0    1649          16.5
# 343  39.1          4          79.0        58.0    1755          16.9
# 345  35.1          4          81.0        60.0    1760          16.1
# 53   31.0          4          71.0        65.0    1773          19.0
# ..    ...        ...           ...         ...     ...           ...
# 95   12.0          8         455.0       225.0    4951          11.0
# 90   12.0          8         429.0       198.0    4952          11.5
# 42   12.0          8         383.0       180.0    4955          11.5
# 103  11.0          8         400.0       150.0    4997          14.0
# 44   13.0          8         400.0       175.0    5140          12.0
#
#      model_year origin                      name
# 54           71  japan               datsun 1200
# 144          74  japan             toyota corona
# 343          81  japan            toyota starlet
# 345          81  japan          honda civic 1300
# 53           71  japan       toyota corolla 1200
# ..          ...    ...                       ...
# 95           73    usa  buick electra 225 custom
# 90           73    usa  mercury marquis brougham
# 42           71    usa         dodge monaco (sw)
# 103          73    usa          chevrolet impala
# 44           71    usa       pontiac safari (sw)
#
# [398 rows x 9 columns]

# %% [markdown]
# **Q4.3 Sort the dataset alphabetically by `name` (A to Z) and display the first 5 rows.**

# %%
# Write your code here
result = df.sort_values(by="name", ascending=True)

print(result.head(5))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 96   13.0          8         360.0       175.0    3821          11.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 66   17.0          8         304.0       150.0    3672          11.5
# 315  24.3          4         151.0        90.0    3003          20.1
# 257  19.4          6         232.0        90.0    3210          17.2
#
#      model_year origin                     name
# 96           73    usa  amc ambassador brougham
# 9            70    usa       amc ambassador dpl
# 66           72    usa       amc ambassador sst
# 315          80    usa              amc concord
# 257          78    usa              amc concord

# %% [markdown]
# # 🧹 **5. Handling Missing Values**
#
# ### _`.isnull().sum()` → count missing values per column | `.fillna(value)` → fill missing | `.dropna()` → drop rows/cols with missing values_
#
# ---

# %% [markdown]
# **Q5.1 Check how many missing values exist in each column of `df`.**

# %%
# Write your code here
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# **Q5.2 Fill any missing values in the `horsepower` column with the column's mean value.**

# %%
# Write your code here
mean_hp = df["horsepower"].mean()

df["horsepower"] = df["horsepower"].fillna(mean_hp)

print(df["horsepower"])
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %% [markdown]
# **Q5.3 Find the total number of missing values in the entire dataset (a single number) using `.isnull().sum().sum()`.**

# %%
# Write your code here
total_missing = df.isnull().sum().sum()

print("Total missing values:", total_missing)
# Out:
# Total missing values: 0

# %% [markdown]
# # 🛠️ **6. Adding, Transforming & Dropping Columns**
#
# ### _Create a column by assignment: `df['new'] = ...` | `.apply(func)` → apply a function/lambda element-wise | `.drop(columns=[...])` → remove columns_
#
# ---

# %% [markdown]
# **Q6.1 Add a new column `weight_kg` by converting `weight` (in lbs) to kilograms (1 lb = 0.4536 kg).**

# %%
# Write your code here
df["weight_kg"] = df["weight"] * 0.4536

print(df[["weight", "weight_kg"]])
# Out:
#      weight  weight_kg
# 0      3504  1589.4144
# 1      3693  1675.1448
# 2      3436  1558.5696
# 3      3433  1557.2088
# 4      3449  1564.4664
# ..      ...        ...
# 393    2790  1265.5440
# 394    2130   966.1680
# 395    2295  1041.0120
# 396    2625  1190.7000
# 397    2720  1233.7920
#
# [398 rows x 2 columns]

# %% [markdown]
# **Q6.2 Add a new column `efficiency` using `.apply()` with a lambda: label a car `'Good'` if `mpg >= 25`, `'Average'` if `15 <= mpg < 25`, else `'Poor'`.**

# %%
# Write your code here
df["efficiency"] = df["mpg"].apply(
    lambda x: "Good" if x >= 25 else ("Average" if x >= 15 else "Poor")
)

print(df[["mpg", "efficiency"]])
# Out:
#       mpg efficiency
# 0    18.0    Average
# 1    15.0    Average
# 2    18.0    Average
# 3    16.0    Average
# 4    17.0    Average
# ..    ...        ...
# 393  27.0       Good
# 394  44.0       Good
# 395  32.0       Good
# 396  28.0       Good
# 397  31.0       Good
#
# [398 rows x 2 columns]

# %% [markdown]
# **Q6.3 Drop the `name` column and store the result in a new DataFrame called `df_numeric`.**

# %%
# Write your code here
df_numeric = df.drop("name", axis=1)

print(df_numeric)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin  weight_kg efficiency
# 0            70     usa  1589.4144    Average
# 1            70     usa  1675.1448    Average
# 2            70     usa  1558.5696    Average
# 3            70     usa  1557.2088    Average
# 4            70     usa  1564.4664    Average
# ..          ...     ...        ...        ...
# 393          82     usa  1265.5440       Good
# 394          82  europe   966.1680       Good
# 395          82     usa  1041.0120       Good
# 396          82     usa  1190.7000       Good
# 397          82     usa  1233.7920       Good
#
# [398 rows x 10 columns]

# %% [markdown]
# **Q6.4 Add a new column `hp_per_weight` by dividing `horsepower` by `weight` for every row.**

# %%
# Write your code here
df["hp_per_weight"] = df["horsepower"] / df["weight"]

print(df[["horsepower", "weight", "hp_per_weight"]])
# Out:
#      horsepower  weight  hp_per_weight
# 0         130.0    3504       0.037100
# 1         165.0    3693       0.044679
# 2         150.0    3436       0.043655
# 3         150.0    3433       0.043694
# 4         140.0    3449       0.040591
# ..          ...     ...            ...
# 393        86.0    2790       0.030824
# 394        52.0    2130       0.024413
# 395        84.0    2295       0.036601
# 396        79.0    2625       0.030095
# 397        82.0    2720       0.030147
#
# [398 rows x 3 columns]

# %% [markdown]
# # 📊 **7. GroupBy & Aggregation**
#
# ### _`.groupby('col')` → split by group | `.mean()`, `.max()`, `.count()` → aggregate | `.agg({...})` → different aggregation per column_
#
# ---

# %% [markdown]
# **Q7.1 Group by `origin` and find the average `mpg` for each origin.**

# %%
# Write your code here
result = df.groupby("origin")["mpg"].mean()

print(result)
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %% [markdown]
# **Q7.2 Group by `cylinders` and find the average `mpg` and the maximum `horsepower` for each group using `.agg()`.**

# %%
# Write your code here
result = df.groupby("cylinders").agg({
    "mpg": "mean",
    "horsepower": "max"
})

print(result)
# Out:
#                  mpg  horsepower
# cylinders
# 3          20.550000       110.0
# 4          29.286765       115.0
# 5          27.366667       103.0
# 6          19.985714       165.0
# 8          14.963107       230.0

# %% [markdown]
# **Q7.3 Group by `model_year` and count how many cars were made each year.**

# %%
# Write your code here
result = df.groupby("model_year").size()

print(result)
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# dtype: int64

# %% [markdown]
# **Q7.4 Group by both `origin` and `cylinders` together, and find the average `mpg` for each combination.**

# %%
# Write your code here
result = df.groupby(["origin", "cylinders"])["mpg"].mean()

print(result)
# Out:
# origin  cylinders
# europe  4            28.411111
#         5            27.366667
#         6            20.100000
# japan   3            20.550000
#         4            31.595652
#         6            23.883333
# usa     4            27.840278
#         6            19.663514
#         8            14.963107
# Name: mpg, dtype: float64

# %% [markdown]
# # 🔢 **8. Value Counts & Unique Values**
#
# ### _`.value_counts()` → frequency of each unique value | `.unique()` → array of distinct values | `.nunique()` → count of distinct values_
#
# ---

# %% [markdown]
# **Q8.1 Use `.value_counts()` to see how many cars come from each `origin`.**

# %%
# Write your code here
result = df["origin"].value_counts()

print(result)
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %% [markdown]
# **Q8.2 Find the number of unique values in `cylinders` and print all the unique values in `model_year`.**

# %%
# Write your code here
# Number of unique values in cylinders
print("Number of unique cylinder values:", df["cylinders"].nunique())

# All unique values in model_year
print("Unique model years:", df["model_year"].unique())
# Out:
# Number of unique cylinder values: 5
# Unique model years: [70 71 72 73 74 75 76 77 78 79 80 81 82]

# %% [markdown]
# **Q8.3 Using `.value_counts()`, find which `model_year` has the highest number of cars.**

# %%
# Write your code here
year_counts = df["model_year"].value_counts()

highest_year = year_counts.idxmax()

print("Model year with the highest number of cars:", highest_year)
print("Number of cars:", year_counts.max())
# Out:
# Model year with the highest number of cars: 73
# Number of cars: 40

# %% [markdown]
# # 🔤 **9. String Operations**
#
# ### _`.str.split()`, `.str.upper()`, `.str.contains()` etc. work on string (object) columns via the `.str` accessor_
#
# ---

# %% [markdown]
# **Q9.1 Create a new column `brand` by extracting the first word from the `name` column (e.g. 'chevrolet chevelle malibu' → 'chevrolet') using `.str.split()`.**

# %%
# Write your code here
df["brand"] = df["name"].str.split().str[0]

print(df[["name", "brand"]])
# Out:
#                           name      brand
# 0    chevrolet chevelle malibu  chevrolet
# 1            buick skylark 320      buick
# 2           plymouth satellite   plymouth
# 3                amc rebel sst        amc
# 4                  ford torino       ford
# ..                         ...        ...
# 393            ford mustang gl       ford
# 394                  vw pickup         vw
# 395              dodge rampage      dodge
# 396                ford ranger       ford
# 397                 chevy s-10      chevy
#
# [398 rows x 2 columns]

# %% [markdown]
# **Q9.2 Create a new column `name_upper` by converting the `name` column to uppercase using `.str.upper()`.**

# %%
# Write your code here
df["name_upper"] = df["name"].str.upper()

print(df[["name", "name_upper"]])
# Out:
#                           name                 name_upper
# 0    chevrolet chevelle malibu  CHEVROLET CHEVELLE MALIBU
# 1            buick skylark 320          BUICK SKYLARK 320
# 2           plymouth satellite         PLYMOUTH SATELLITE
# 3                amc rebel sst              AMC REBEL SST
# 4                  ford torino                FORD TORINO
# ..                         ...                        ...
# 393            ford mustang gl            FORD MUSTANG GL
# 394                  vw pickup                  VW PICKUP
# 395              dodge rampage              DODGE RAMPAGE
# 396                ford ranger                FORD RANGER
# 397                 chevy s-10                 CHEVY S-10
#
# [398 rows x 2 columns]

# %% [markdown]
# **Q9.3 Use `.str.contains('ford', case=False)` to filter all cars whose name contains 'ford'.**

# %%
# Write your code here
result = df[df["name"].str.contains("ford", case=False)]

print(result)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 4    17.0          8         302.0  140.000000    3449          10.5
# 5    15.0          8         429.0  198.000000    4341          10.0
# 17   21.0          6         200.0   85.000000    2587          16.0
# 25   10.0          8         360.0  215.000000    4615          14.0
# 32   25.0          4          98.0  104.469388    2046          19.0
# 36   19.0          6         250.0   88.000000    3302          15.5
# 40   14.0          8         351.0  153.000000    4154          13.5
# 43   13.0          8         400.0  170.000000    4746          12.0
# 48   18.0          6         250.0   88.000000    3139          14.5
# 61   21.0          4         122.0   86.000000    2226          16.5
# 65   14.0          8         351.0  153.000000    4129          13.0
# 74   13.0          8         302.0  140.000000    4294          16.0
# 80   22.0          4         122.0   86.000000    2395          16.0
# 88   14.0          8         302.0  137.000000    4042          14.5
# 92   13.0          8         351.0  158.000000    4363          13.0
# 100  18.0          6         250.0   88.000000    3021          16.5
# 104  12.0          8         400.0  167.000000    4906          12.5
# 112  19.0          4         122.0   85.000000    2310          18.5
# 126  21.0          6         200.0  104.469388    2875          17.0
# 130  26.0          4         122.0   80.000000    2451          16.5
# 136  16.0          8         302.0  140.000000    4141          14.0
# 139  14.0          8         302.0  140.000000    4638          16.0
# 155  15.0          6         250.0   72.000000    3158          19.5
# 159  14.0          8         351.0  148.000000    4657          13.5
# 166  13.0          8         302.0  129.000000    3169          12.0
# 168  23.0          4         140.0   83.000000    2639          17.0
# 174  18.0          6         171.0   97.000000    2984          14.5
# 190  14.5          8         351.0  152.000000    4215          12.8
# 193  24.0          6         200.0   81.000000    3012          17.6
# 200  18.0          6         250.0   78.000000    3574          21.0
# 206  26.5          4         140.0   72.000000    2565          13.6
# 214  13.0          8         302.0  130.000000    3870          15.0
# 228  18.5          6         250.0   98.000000    3525          19.0
# 232  16.0          8         351.0  149.000000    4335          14.5
# 236  25.5          4         140.0   89.000000    2755          15.8
# 245  36.1          4          98.0   66.000000    1800          14.4
# 254  20.2          6         200.0   85.000000    2965          15.8
# 255  25.1          4         140.0   88.000000    2720          15.4
# 264  18.1          8         302.0  139.000000    3205          11.2
# 282  22.3          4         140.0   88.000000    2890          17.3
# 286  17.6          8         302.0  129.000000    3725          13.4
# 290  15.5          8         351.0  142.000000    4054          14.3
# 314  26.4          4         140.0   88.000000    2870          18.1
# 336  23.6          4         140.0  104.469388    2905          14.3
# 351  34.4          4          98.0   65.000000    2045          16.2
# 352  29.9          4          98.0   65.000000    2380          20.7
# 365  20.2          6         200.0   88.000000    3060          17.1
# 373  24.0          4         140.0   92.000000    2865          16.4
# 389  22.0          6         232.0  112.000000    2835          14.7
# 393  27.0          4         140.0   86.000000    2790          15.6
# 396  28.0          4         120.0   79.000000    2625          18.6
#
#      model_year origin                      name  weight_kg efficiency  \
# 4            70    usa               ford torino  1564.4664    Average
# 5            70    usa          ford galaxie 500  1969.0776    Average
# 17           70    usa             ford maverick  1173.4632    Average
# 25           70    usa                 ford f250  2093.3640       Poor
# 32           71    usa                ford pinto   928.0656       Good
# 36           71    usa           ford torino 500  1497.7872    Average
# 40           71    usa          ford galaxie 500  1884.2544       Poor
# 43           71    usa  ford country squire (sw)  2152.7856       Poor
# 48           71    usa              ford mustang  1423.8504    Average
# 61           72    usa       ford pinto runabout  1009.7136    Average
# 65           72    usa          ford galaxie 500  1872.9144       Poor
# 74           72    usa     ford gran torino (sw)  1947.7584       Poor
# 80           72    usa           ford pinto (sw)  1086.3720    Average
# 88           73    usa          ford gran torino  1833.4512       Poor
# 92           73    usa                  ford ltd  1979.0568       Poor
# 100          73    usa             ford maverick  1370.3256    Average
# 104          73    usa              ford country  2225.3616       Poor
# 112          73    usa                ford pinto  1047.8160    Average
# 126          74    usa             ford maverick  1304.1000    Average
# 130          74    usa                ford pinto  1111.7736       Good
# 136          74    usa          ford gran torino  1878.3576    Average
# 139          74    usa     ford gran torino (sw)  2103.7968       Poor
# 155          75    usa             ford maverick  1432.4688    Average
# 159          75    usa                  ford ltd  2112.4152       Poor
# 166          75    usa           ford mustang ii  1437.4584       Poor
# 168          75    usa                ford pinto  1197.0504    Average
# 174          75    usa                ford pinto  1353.5424    Average
# 190          76    usa          ford gran torino  1911.9240       Poor
# 193          76    usa             ford maverick  1366.2432    Average
# 200          76    usa         ford granada ghia  1621.1664    Average
# 206          76    usa                ford pinto  1163.4840       Good
# 214          76    usa                 ford f108  1755.4320       Poor
# 228          77    usa              ford granada  1598.9400    Average
# 232          77    usa          ford thunderbird  1966.3560    Average
# 236          77    usa       ford mustang ii 2+2  1249.6680       Good
# 245          78    usa               ford fiesta   816.4800       Good
# 254          78    usa      ford fairmont (auto)  1344.9240    Average
# 255          78    usa       ford fairmont (man)  1233.7920       Good
# 264          78    usa               ford futura  1453.7880    Average
# 282          79    usa           ford fairmont 4  1310.9040    Average
# 286          79    usa           ford ltd landau  1689.6600    Average
# 290          79    usa  ford country squire (sw)  1838.8944    Average
# 314          80    usa             ford fairmont  1301.8320       Good
# 336          80    usa        ford mustang cobra  1317.7080    Average
# 351          81    usa            ford escort 4w   927.6120       Good
# 352          81    usa            ford escort 2h  1079.5680       Good
# 365          81    usa           ford granada gl  1388.0160    Average
# 373          82    usa      ford fairmont futura  1299.5640    Average
# 389          82    usa            ford granada l  1285.9560    Average
# 393          82    usa           ford mustang gl  1265.5440       Good
# 396          82    usa               ford ranger  1190.7000       Good
#
#      hp_per_weight brand                name_upper
# 4         0.040591  ford               FORD TORINO
# 5         0.045612  ford          FORD GALAXIE 500
# 17        0.032857  ford             FORD MAVERICK
# 25        0.046587  ford                 FORD F250
# 32        0.051060  ford                FORD PINTO
# 36        0.026651  ford           FORD TORINO 500
# 40        0.036832  ford          FORD GALAXIE 500
# 43        0.035820  ford  FORD COUNTRY SQUIRE (SW)
# 48        0.028034  ford              FORD MUSTANG
# 61        0.038634  ford       FORD PINTO RUNABOUT
# 65        0.037055  ford          FORD GALAXIE 500
# 74        0.032604  ford     FORD GRAN TORINO (SW)
# 80        0.035908  ford           FORD PINTO (SW)
# 88        0.033894  ford          FORD GRAN TORINO
# 92        0.036214  ford                  FORD LTD
# 100       0.029129  ford             FORD MAVERICK
# 104       0.034040  ford              FORD COUNTRY
# 112       0.036797  ford                FORD PINTO
# 126       0.036337  ford             FORD MAVERICK
# 130       0.032640  ford                FORD PINTO
# 136       0.033808  ford          FORD GRAN TORINO
# 139       0.030185  ford     FORD GRAN TORINO (SW)
# 155       0.022799  ford             FORD MAVERICK
# 159       0.031780  ford                  FORD LTD
# 166       0.040707  ford           FORD MUSTANG II
# 168       0.031451  ford                FORD PINTO
# 174       0.032507  ford                FORD PINTO
# 190       0.036062  ford          FORD GRAN TORINO
# 193       0.026892  ford             FORD MAVERICK
# 200       0.021824  ford         FORD GRANADA GHIA
# 206       0.028070  ford                FORD PINTO
# 214       0.033592  ford                 FORD F108
# 228       0.027801  ford              FORD GRANADA
# 232       0.034371  ford          FORD THUNDERBIRD
# 236       0.032305  ford       FORD MUSTANG II 2+2
# 245       0.036667  ford               FORD FIESTA
# 254       0.028668  ford      FORD FAIRMONT (AUTO)
# 255       0.032353  ford       FORD FAIRMONT (MAN)
# 264       0.043370  ford               FORD FUTURA
# 282       0.030450  ford           FORD FAIRMONT 4
# 286       0.034631  ford           FORD LTD LANDAU
# 290       0.035027  ford  FORD COUNTRY SQUIRE (SW)
# 314       0.030662  ford             FORD FAIRMONT
# 336       0.035962  ford        FORD MUSTANG COBRA
# 351       0.031785  ford            FORD ESCORT 4W
# 352       0.027311  ford            FORD ESCORT 2H
# 365       0.028758  ford           FORD GRANADA GL
# 373       0.032112  ford      FORD FAIRMONT FUTURA
# 389       0.039506  ford            FORD GRANADA L
# 393       0.030824  ford           FORD MUSTANG GL
# 396       0.030095  ford               FORD RANGER

# %% [markdown]
# # 🧾 **10. Duplicates & Renaming**
#
# ### _`.duplicated()` → boolean mask of duplicate rows | `.drop_duplicates()` → remove them | `.rename(columns={...})` → rename columns_
#
# ---

# %% [markdown]
# **Q10.1 Check whether `df` has any duplicate rows using `.duplicated()`, then remove them with `.drop_duplicates()`.**

# %%
# Write your code here
# Check duplicate rows
print("Duplicate rows:", df.duplicated().sum())

# Remove duplicate rows
df = df.drop_duplicates()

print("Duplicates after removal:", df.duplicated().sum())
# Out:
# Duplicate rows: 0
# Duplicates after removal: 0

# %% [markdown]
# **Q10.2 Rename the `model_year` column to `year` and the `horsepower` column to `hp`.**

# %%
# Write your code here
df = df.rename(columns={
    "model_year": "year",
    "horsepower": "hp"
})

print(df.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'hp', 'weight', 'acceleration',
#        'year', 'origin', 'name', 'weight_kg', 'efficiency', 'hp_per_weight',
#        'brand', 'name_upper'],
#       dtype='object')

# %% [markdown]
# **Q10.3 Rename every column name to uppercase in one line, using `.rename(columns=...)` with a dictionary comprehension.**

# %%
# Write your code here
df = df.rename(columns={col: col.upper() for col in df.columns})

# %% [markdown]
# # 🔗 **11. Merge & Concat**
#
# ### _`pd.merge(df1, df2, on='col')` → join two DataFrames on a common column | `pd.concat([df1, df2])` → stack DataFrames together_
#
# ---

# %% [markdown]
# **Q11.1 Create a small lookup DataFrame mapping `origin` codes to full names (`'usa' -> 'United States'`, `'japan' -> 'Japan'`, `'europe' -> 'Europe'`) and merge it with `df` on the `origin` column.**

# %%
# Write your code here
lookup = pd.DataFrame({
    "origin": ["usa", "japan", "europe"],
    "full_name": ["United States", "Japan", "Europe"]
})

df = df.merge(lookup, on="origin", how="left")

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/yt/n_1y0wdj5s32bsrm17h2xnbc0000gn/T/ipykernel_69045/2146211145.py in ?()
# ----> 7 # Write your code here
#       8 lookup = pd.DataFrame({
#       9     "origin": ["usa", "japan", "europe"],
#      10     "full_name": ["United States", "Japan", "Europe"]
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1307                     if lk is not None:
#    1308                         # Then we're either Hashable or a wrong-length arraylike,
#    1309                         #  the latter of which will raise
#    1310                         lk = cast(Hashable, lk)
# -> 1311                         left_keys.append(left._get_label_or_level_values(lk))
#    1312                         join_names.append(lk)
#    1313                     else:
#    1314                         # work-around for merge_asof(left_index=True)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'origin'

# %% [markdown]
# **Q11.2 Create two smaller DataFrames — the first 5 rows and the last 5 rows of `df` — and combine them back together using `pd.concat()`.**

# %%
# Write your code here

# %% [markdown]
# **Q11.3 From the merged DataFrame in Q11.1, display only the `name`, `origin`, and the new full-name column for the first 5 rows.**

# %%
# Write your code here

# %% [markdown]
# # 💾 **12. Exporting Data**
#
# ### _`.to_csv('filename.csv', index=False)` → save a DataFrame to a CSV file_
#
# ---

# %% [markdown]
# **Q12.1 Filter cars with `mpg > 25`, then save the result to a new file called `efficient_cars.csv` (without the index column).**

# %%
# Write your code here

# %% [markdown]
# **Q12.2 Filter cars with `cylinders == 8` and save them to a file called `eight_cylinder_cars.csv`.**

# %%
# Write your code here

# %% [markdown]
# **Q12.3 Read back the `efficient_cars.csv` file you saved in Q12.1 using `pd.read_csv()`, and confirm it loaded correctly by checking its shape.**

# %%
# Write your code here
