# %%
! pip3 install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
restaurant_data={
    'Table_no':[12,13,15],
    'Bill Amount':[1250,1345,5434],
    'Waiter_Name':['alloo','bhallo','challo']
}
df=pd.DataFrame(restaurant_data)

print(df['bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       1 restaurant_data={
#       2     'Table_no':[12,13,15],
#       3     'Bill Amount':[1250,1345,5434],
#       4     'Waiter_Name':['alloo','bhallo','challo']
#       5 }
# ----> 6 df=pd.DataFrame(restaurant_data)
#       8 print(df['bill_Amount'])
#       9 print(type(df['Bill_Amount']))
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np                              
restaurant_data={
    'Table_no':[12,13,15],
    'Bill_Amount':[1250,1345,5434],
    'Waiter_Name':['alloo','bhallo','challo']
}
df=pd.DataFrame(restaurant_data)

print(df['Bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 restaurant_data={
#       4     'Table_no':[12,13,15],
#       5     'Bill_Amount':[1250,1345,5434],
#       6     'Waiter_Name':['alloo','bhallo','challo']
#       7 }
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np                              
restaurant_data={
    'Table_no':[12,13,15],
    'Bill Amount':[1250,1345,5434],
    'Waiter_Name':['alloo','bhallo','challo']
}
df=pd.DataFrame(restaurant_data)

print(df['Bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 restaurant_data={
#       4     'Table_no':[12,13,15],
#       5     'Bill Amount':[1250,1345,5434],
#       6     'Waiter_Name':['alloo','bhallo','challo']
#       7 }
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np                              
restaurant_data={
    'Table_no':[12,13,15],
    'Bill Amount':[1250,1345,5434],
    'Waiter_Name':['alloo','bhallo','challo']
}
df=pd.DataFrame(restaurant_data)

print(df['Bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 restaurant_data={
#       4     'Table_no':[12,13,15],
#       5     'Bill Amount':[1250,1345,5434],
#       6     'Waiter_Name':['alloo','bhallo','challo']
#       7 }
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np                              
restaurant_data={
    'Table_no':[12,13,15],
    'Bill Amount':[1250,1345,5434],
    'Waiter_Name':['alloo','bhallo','challo']
}
df=pd.DataFrame(restaurant_data)

print(df['Bill_Amount'])
print(type(df['Bill_Amount']))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 restaurant_data={
#       4     'Table_no':[12,13,15],
#       5     'Bill Amount':[1250,1345,5434],
#       6     'Waiter_Name':['alloo','bhallo','challo']
#       7 }
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# %pip install pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 1.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 2.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 348 kB 2.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 508 kB 3.3 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np                              
restaurant_data={
    'Table_no':[12,13,15],
    'Bill Amount':[1250,1345,5434],
    'Waiter_Name':['alloo','bhallo','challo']
}
df=pd.DataFrame(restaurant_data)

print(df['Bill Amount'])
print(type(df['Bill Amount']))
# Out:
# 0    1250
# 1    1345
# 2    5434
# Name: Bill Amount, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd

df = pd.read_csv("restaurant.csv")

print(df['total_bill'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("restaurant.csv")
#       5 print(df['total_bill'])
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.DataFrame({
    'total_bill': [16.99, 10.34, 21.01, 23.68],
    'day': ['Sun', 'Sun', 'Sun', 'Sun'],
    'tip': [1.01, 1.66, 3.50, 3.31]
})
x = df['day']
print(x)
# Out:
# 0    Sun
# 1    Sun
# 2    Sun
# 3    Sun
# Name: day, dtype: object
