# %%
import sys
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('/Users/prishitasingh/Desktop/Machine Learning/pandas/Titanic-Dataset.csv')
tip= pd.read_csv('/Users/prishitasingh/Desktop/Machine Learning/pandas/tip.csv')

print(tip.shape,titanic.shape)
# Out:
# (244, 7) (891, 12)

# %%
# how many bills on each day 

tip.groupby('day').size()
tip.groupby('day')['tip'].mean().round(2)
# Out:
# day
# Fri     2.73
# Sat     2.99
# Sun     3.26
# Thur    2.77
# Name: tip, dtype: float64

# %%
# make a tip_pct column ,then average it per day 
tip['tip_pct'] = round(tip['tip'] / tip['total_bill'] * 100, 2)

tip.head(2)

tip.groupby('day')['tip_pct'].mean().round(2)
# Out:
# day
# Fri     16.99
# Sat     15.31
# Sun     16.69
# Thur    16.13
# Name: tip_pct, dtype: float64

# %%
tip.groupby('day').mean(numeric_only=True)
tip.groupby('day')['tip'].mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
tip.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2     5.94

# %%
titanic.groupby('Pclass')["Survived"].mean().round(2)*100
# Out:
# Pclass
# 1    63.0
# 2    47.0
# 3    24.0
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass')["Fare"].mean().round(2)*100
# Out:
# Pclass
# 1    8415.0
# 2    2066.0
# 3    1368.0
# Name: Fare, dtype: float64
